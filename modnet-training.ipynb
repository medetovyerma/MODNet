# %%
# !git clone https://github.com/PP22MotionLearning/MODNet
# %cd MODNet

# %%
# !pip install numpy
# !pip install segmentation-models-pytorch
# !pip install gdown
# !pip install neptune-client

# %%
# !mkdir models
# %cd pretrained
# !gdown --id 1gNJXQPUBBp2mbA4q1Giz5mzv3EpxR7lq
# %cd ..

# %%
# !ls

# %%
# !python3 -m src.train.train --datasetPath /kaggle/input/aisegmentcom-matting-human-datasets --modelsPath models/ --batchCount 2
